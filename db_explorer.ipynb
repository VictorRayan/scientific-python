# %%
import pandas as pd

# Show all columns in pandas dataframe when printing to stdout
pd.set_option("display.max_columns", None)

datafile='magnetic-dimensionality-v100.csv'
df0 = pd.read_csv(datafile, ';')
#print(df0.keys())



# Drop all the columns except these ones
df = df0[['icsd_code','dimension', 'chemical_structural_formula', 'num_atoms', 'space_group_symmetry', 'number_index', 'structure_type', 'valence', 'metal_neigh_coordination', 'partial_occupancy']].copy()

# Print only materials with a given number of atoms, two-dimensional and no partial occupancy of atomic sites
#print(df[ (df.num_atoms<=3) & (df.dimension==2) & (df.partial_occupancy=='no') ])

#saves the filtered data from Dataframe 'df'
df[ (df.num_atoms<=3) & (df.dimension==2) & (df.partial_occupancy=='no') ].to_csv('filtered-magnetic.csv')
# Out:
# /home/rayan/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        error_code  icsd_code  dimension  lower_index  upper_index  \
# 0               0       2259          0         -1.0         -1.0
# 1               0       2260          0         -1.0         -1.0
# 2               0       2402          1          0.0          0.0
# 3               0       2828          1          0.0          0.0
# 4               0       6075          1          0.1          0.1
# ...           ...        ...        ...          ...          ...
# 46647           0      65082          2          1.9          1.9
# 46648           0      65082          1          2.0          2.1
# 46649           0      56791          1          1.5          1.6
# 46650           0      59653          2          1.9          1.9
# 46651           0     180301          2          0.2          0.3
#
#                     direction chemical_structural_formula  \
# 0                           0                'Cr (O D) O'
# 1                           0                'Cr (O H) O'
# 2            [ 0.   0.5  0. ]                'K2 (Cr O4)'
# 3            [ 0.   0.   0.5]                'K2 (Cr O4)'
# 4            [ 0.   0.   0.5]   'Pb6 (Cr O6) Cl6 (H2 O)2'
# ...                       ...                         ...
# 46647           [-1.  0.  0.]           'Cu4 Fe Pb Bi S6'
# 46648        [ 0.   0.   0.5]           'Cu4 Fe Pb Bi S6'
# 46649        [ 0.   0.5  0. ]            'Bi2 Pb2 V2 O10'
# 46650  [ 0.     0.    -1.002]       'Ba42 Ti51 Fe20 O174'
# 46651           [ 0.  0. -1.]            'K La Mn (W O6)'
#
#         chemical_formula_sum  cell_volume  num_atoms space_group_symmetry  \
# 0                'D1 Cr1 O2'        62.55         10            'P n n m'
# 1                'H1 Cr1 O2'        62.59         10            'P n n m'
# 2                'Cr1 K2 O4'       471.25         28            'P n m a'
# 3                'Cr1 K2 O4'       471.41         28            'P n a m'
# 4        'H4 Cl6 Cr1 O8 Pb6'      1408.34         63             'R -3 H'
# ...                      ...          ...        ...                  ...
# 46647   'Bi1 Cu4 Fe1 Pb1 S6'       505.92         26           'P b 21 m'
# 46648   'Bi1 Cu4 Fe1 Pb1 S6'       505.92         26           'P b 21 m'
# 46649       'Bi2 O10 Pb2 V2'       245.70         16               'P -1'
# 46650  'Ba42 Fe20 O174 Ti51'      7272.04        574          'C 1 2/m 1'
# 46651     'K1 La1 Mn1 O6 W1'     13050.43       1000           'P -4 2 m'
#
#        number_index    time  structure_type_number structure_type  delta  \
# 0                58    4.82                     -1          InOOH   -1.0
# 1                58    0.34                     -1          InOOH   -1.0
# 2                62    0.52                      0    K2SO4(beta)    0.0
# 3                62    0.52                      0    K2SO4(beta)    0.0
# 4               148    1.44                      1            NaN    0.1
# ...             ...     ...                    ...            ...    ...
# 46647            26    0.93                   6172            NaN    1.9
# 46648            26    3.77                   5099            NaN    2.0
# 46649             2    0.47                   5073        BiMnVO5    1.6
# 46650            12  318.61                   4088            NaN   -1.0
# 46651           111  574.27                   6056            NaN    0.3
#
#                                             layer_anions  \
# 0                                                     -1
# 1                                                     -1
# 2      {'3Cr1': ['O1'], '2Cr1': ['O1'], '1Cr1': ['O1'...
# 3      {'3Cr1': ['O1'], '2Cr1': ['O1'], '1Cr1': ['O1'...
# 4       {'2Cr1': ['O1'], '1Cr1': ['O1'], '0Cr1': ['O1']}
# ...                                                  ...
# 46647  {'0Fe1': ['S1', 'Bi1'], '7Cu1': ['S1', 'Bi1'],...
# 46648  {'0Fe1': ['S1'], '8Cu1': ['S1'], '4Cu1': ['S1'...
# 46649       {'0V1': ['O1', 'Bi1'], '1V1': ['O1', 'Bi1']}
# 46650                                                 -1
# 46651                                    {'Mn1': ['O1']}
#
#                                                  valence  \
# 0                                                     -1
# 1                                                     -1
# 2       {'3Cr1': -1, '2Cr1': -1, '1Cr1': -1, '0Cr1': -1}
# 3       {'3Cr1': -1, '2Cr1': -1, '1Cr1': -1, '0Cr1': -1}
# 4                   {'2Cr1': -1, '1Cr1': -1, '0Cr1': -1}
# ...                                                  ...
# 46647  {'0Fe1': 3, '7Cu1': 2, '3Cu1': 2, '8Cu1': 1, '...
# 46648  {'0Fe1': 3, '8Cu1': 1, '4Cu1': 1, '9Cu1': 1, '...
# 46649                             {'0V1': -1, '1V1': -1}
# 46650                                                 -1
# 46651                                        {'Mn1': -1}
#
#                                            bonded_anions  \
# 0                                                     -1
# 1                                                     -1
# 2      {'3Cr1': ['O1', 'O1', 'O1', 'O1', 'O1', 'O1'],...
# 3      {'3Cr1': ['O1', 'O1', 'O1', 'O1', 'O1', 'O1'],...
# 4      {'2Cr1': ['O1', 'O1', 'O1', 'O1', 'O1', 'O1', ...
# ...                                                  ...
# 46647  {'0Fe1': ['S1', 'S1', 'S1', 'S1'], '7Cu1': ['S...
# 46648  {'0Fe1': ['S1'], '8Cu1': [], '4Cu1': [], '9Cu1...
# 46649  {'0V1': ['O1', 'O1', 'O1', 'O1'], '1V1': ['O1'...
# 46650                                                 -1
# 46651      {'Mn1': ['O1', 'O1', 'O1', 'O1', 'O1', 'O1']}
#
#                                      bonded_coordination  \
# 0                                                     -1
# 1                                                     -1
# 2           {'3Cr1': 6, '2Cr1': 6, '1Cr1': 6, '0Cr1': 6}
# 3           {'3Cr1': 6, '2Cr1': 6, '1Cr1': 6, '0Cr1': 6}
# 4                      {'2Cr1': 8, '1Cr1': 8, '0Cr1': 8}
# ...                                                  ...
# 46647  {'0Fe1': 4, '7Cu1': 2, '3Cu1': 4, '8Cu1': 3, '...
# 46648  {'0Fe1': 1, '8Cu1': 0, '4Cu1': 0, '9Cu1': 0, '...
# 46649                               {'0V1': 4, '1V1': 4}
# 46650                                                 -1
# 46651                                         {'Mn1': 6}
#
#                                              bonded_rank  \
# 0                                                     -1
# 1                                                     -1
# 2           {'3Cr1': 3, '2Cr1': 3, '1Cr1': 3, '0Cr1': 3}
# 3           {'3Cr1': 3, '2Cr1': 3, '1Cr1': 3, '0Cr1': 3}
# 4                      {'2Cr1': 3, '1Cr1': 3, '0Cr1': 3}
# ...                                                  ...
# 46647  {'0Fe1': 3, '7Cu1': 2, '3Cu1': 3, '8Cu1': 3, '...
# 46648  {'0Fe1': 1, '8Cu1': 0, '4Cu1': 0, '9Cu1': 0, '...
# 46649                               {'0V1': 3, '1V1': 3}
# 46650                                                 -1
# 46651                                         {'Mn1': 3}
#
#                                    pymatgen_coordination  \
# 0                                                     -1
# 1                                                     -1
# 2      {'3Cr1': '4.0', '2Cr1': '4.0', '1Cr1': '4.0', ...
# 3      {'3Cr1': '4.0', '2Cr1': '4.0', '1Cr1': '4.0', ...
# 4          {'2Cr1': '6.0', '1Cr1': '6.0', '0Cr1': '6.0'}
# ...                                                  ...
# 46647  {'0Fe1': '5.95', '7Cu1': '4.77', '3Cu1': '4.3'...
# 46648  {'0Fe1': '5.95', '8Cu1': '4.3', '4Cu1': '4.77'...
# 46649                     {'0V1': '4.02', '1V1': '4.02'}
# 46650                                                 -1
# 46651                                    {'Mn1': '5.58'}
#
#                       metal_neigh_angle metal_neigh_coordination  \
# 0                                    -1                       -1
# 1                                    -1                       -1
# 2                      {'Cr1': '74.22'}               {'Cr1': 2}
# 3                      {'Cr1': '74.24'}               {'Cr1': 2}
# 4                      {'Cr1': '180.0'}               {'Cr1': 2}
# ...                                 ...                      ...
# 46647   {'Cu1': '90.0', 'Fe1': '180.0'}     {'Cu1': 1, 'Fe1': 2}
# 46648  {'Cu1': '59.51', 'Fe1': '180.0'}     {'Cu1': 4, 'Fe1': 2}
# 46649                   {'V1': '81.09'}                {'V1': 1}
# 46650                                -1                       -1
# 46651                  {'Mn1': '60.86'}               {'Mn1': 8}
#
#            metal_neigh_rank  \
# 0                        -1
# 1                        -1
# 2                {'Cr1': 2}
# 3                {'Cr1': 2}
# 4                {'Cr1': 1}
# ...                     ...
# 46647  {'Cu1': 1, 'Fe1': 1}
# 46648  {'Cu1': 2, 'Fe1': 1}
# 46649             {'V1': 1}
# 46650                    -1
# 46651            {'Mn1': 3}
#
#                                           bonded_lattice  \
# 0                                                     -1
# 1                                                     -1
# 2      {'3Cr1': {'octahedral': '56.7'}, '2Cr1': {'oct...
# 3      {'3Cr1': {'octahedral': '65.0'}, '2Cr1': {'oct...
# 4      {'2Cr1': {'bcc': '92.4'}, '1Cr1': {'bcc': '89....
# ...                                                  ...
# 46647  {'0Fe1': {'square_planar': '33.6', 'tetrahedra...
# 46648  {'0Fe1': -1, '8Cu1': -1, '4Cu1': -1, '9Cu1': -...
# 46649  {'0V1': {'square_planar': '34.0', 'tetrahedral...
# 46650                                                 -1
# 46651                    {'Mn1': {'octahedral': '55.4'}}
#
#                                      metal_neigh_lattice partial_occupancy
# 0                                                     -1               yes
# 1                                                     -1               yes
# 2                            {'Cr1': {'linear': '63.6'}}                no
# 3                            {'Cr1': {'linear': '63.6'}}                no
# 4                             {'Cr1': {'linear': '0.0'}}                no
# ...                                                  ...               ...
# 46647              {'Cu1': -1, 'Fe1': {'linear': '0.0'}}                no
# 46648  {'Cu1': {'square_planar': '76.8'}, 'Fe1': {'li...                no
# 46649                                         {'V1': -1}                no
# 46650                                                 -1               yes
# 46651                                        {'Mn1': -1}                no
#
# [46652 rows x 28 columns]

# %%
# Dictionary with the data gathered in the search
gathered_data={'material':[],'search_word':[],'search_result':[]}

# List of materials to be searched
lista_de_materiais=['CrSe2','VI2','V2C',...]

# List of words to be searched for
lista_de_termos=['magnetism','insulator','metal',...]

# Loop over material and search words
# 'google_search_for()' should be substituted with appropriate method from google API
for mat in lista_de_materiais:
  for word in lista_de_termos:
    gathered_data['material'].append(mat)
    gathered_data['search_word'].append(word)
    gathered_data['search_result'].append(google_search_for(mat,word))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6809/2591673526.py in <module>
#      14     gathered_data['material'].append(mat)
#      15     gathered_data['search_word'].append(word)
# ---> 16     gathered_data['search_result'].append(google_search_for(mat,word))
#
# NameError: name 'google_search_for' is not defined
